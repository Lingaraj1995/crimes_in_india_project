# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('crime_data.csv')

# %%
df
# Out:
#                    Row Labels  Sum of Population in 2011  \
# 0   Andaman & Nicobar Islands                     380581
# 1              Andhra Pradesh                   49386799
# 2           Arunachal Pradesh                    1383727
# 3                       Assam                   31205576
# 4                       Bihar                  104099452
# 5                  Chandigarh                    1055450
# 6                Chhattisgarh                   25545198
# 7        Dadra & Nagar Haveli                     343709
# 8                 Daman & Diu                     243247
# 9                       Delhi                   16787941
# 10                        Goa                    1458545
# 11                    Gujarat                   60439692
# 12                    Haryana                   25351462
# 13           Himachal Pradesh                    6864602
# 14            Jammu & Kashmir                   12541302
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Labels                 36 non-null     object
#  1   Sum of Population in 2011  36 non-null     int64
#  2   Sum of Population in 2001  36 non-null     int64
#  3   2001 - LIT                 30 non-null     float64
#  4   2011- LIT                  30 non-null     float64
#  5   2001 -UNEMP                30 non-null     float64
#  6   2011 -UNEMP                30 non-null     float64
#  7   2001-Murder                16 non-null     float64
#  8   2011-Murder                16 non-null     float64
#  9   2001-Rape                  16 non-null     float64
#  10  2011-Rape                  16 non-null     float64
#  11  2001-kidnap and abdyction  16 non-null     float64
#  12  2011-kidnap and abdyction  16 non-null     float64
# ...

# %%
df.describe()
# Out:
#        Sum of Population in 2011  Sum of Population in 2001  2001 - LIT  \
# count               3.600000e+01               3.600000e+01   30.000000
# mean                3.363486e+07               2.857604e+07   69.329667
# std                 4.305205e+07               3.614914e+07   10.908393
# min                 6.447300e+04               6.065000e+04   47.000000
# 25%                 1.439840e+06               1.285243e+06   63.122500
# 50%                 2.106970e+07               1.734216e+07   68.975000
# 75%                 5.215002e+07               4.658481e+07   77.855000
# max                 1.998123e+08               1.661979e+08   90.860000
#
#        2011- LIT  2001 -UNEMP  2011 -UNEMP  2001-Murder  2011-Murder  \
# count  30.000000    30.000000    30.000000    16.000000    16.000000
# mean   77.690667    22.333333    30.966667  1881.312500  1818.625000
# std     8.828697    21.945596    33.072004  1803.652099  1241.007165
# ...

# %%
df1=df.dropna(axis=0)

# %%
df1
# Out:
#           Row Labels  Sum of Population in 2011  Sum of Population in 2001  \
# 1     Andhra Pradesh                   49386799                   45222736
# 4              Bihar                  104099452                   82998509
# 9              Delhi                   16787941                   13850507
# 11           Gujarat                   60439692                   50671017
# 12           Haryana                   25351462                   21144564
# 13  Himachal Pradesh                    6864602                    6077900
# 16         Karnataka                   61095297                   52850562
# 17            Kerala                   33406061                   31841374
# 19    Madhya Pradesh                   72626809                   60348023
# 20       Maharashtra                  112374333                   96878627
# 25   Odisha (Orissa)                   41974218                   36804660
# ...

# %%
df1.shape
# Out:
# (16, 17)

# %% [markdown]
# # 2.1	Analysis of Literacy Rate vs Total Crimes.

# %%
sns.lineplot(x='2001 - LIT',y='2001-total crime',data=df1)
# Out:
# <Axes: xlabel='2001 - LIT', ylabel='2001-total crime'>

# %%
sns.lineplot(x='2011- LIT',y='2011-total crime',data=df1)
# Out:
# <Axes: xlabel='2011- LIT', ylabel='2011-total crime'>

# %%
sns.regplot(x='2011- LIT',y='2011-total crime',data=df1)
# Out:
# <Axes: xlabel='2011- LIT', ylabel='2011-total crime'>

# %%
sns.regplot(x='2001 - LIT',y='2001-total crime',data=df1)
# Out:
# <Axes: xlabel='2001 - LIT', ylabel='2001-total crime'>

# %% [markdown]
# # 2.2	 Analysis of the type of crime vs each state vs Literacy rate.

# %%
df1
# Out:
#           Row Labels  Sum of Population in 2011  Sum of Population in 2001  \
# 1     Andhra Pradesh                   49386799                   45222736
# 4              Bihar                  104099452                   82998509
# 9              Delhi                   16787941                   13850507
# 11           Gujarat                   60439692                   50671017
# 12           Haryana                   25351462                   21144564
# 13  Himachal Pradesh                    6864602                    6077900
# 16         Karnataka                   61095297                   52850562
# 17            Kerala                   33406061                   31841374
# 19    Madhya Pradesh                   72626809                   60348023
# 20       Maharashtra                  112374333                   96878627
# 25   Odisha (Orissa)                   41974218                   36804660
# ...

# %%
plt.figure(figsize=(25,20))
sns.lmplot(hue='Row Labels',x='2001 - LIT',y='2001-Murder',data=df1)

# %%
plt.figure(figsize=(25,20))
sns.lmplot(hue='Row Labels',x='2001 - LIT',y='2001-Rape',data=df1)

# %%
plt.figure(figsize=(25,20))
sns.lmplot(hue='Row Labels',x='2001 - LIT',y='2001-kidnap and abdyction',data=df1)

# %%
plt.figure(figsize=(25,20))
sns.lmplot(hue='Row Labels',x='2001 - LIT',y='2001-property crime',data=df1)

# %%
plt.figure(figsize=(25,20))
sns.heatmap(df1.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
df1
# Out:
#           Row Labels  Sum of Population in 2011  Sum of Population in 2001  \
# 1     Andhra Pradesh                   49386799                   45222736
# 4              Bihar                  104099452                   82998509
# 9              Delhi                   16787941                   13850507
# 11           Gujarat                   60439692                   50671017
# 12           Haryana                   25351462                   21144564
# 13  Himachal Pradesh                    6864602                    6077900
# 16         Karnataka                   61095297                   52850562
# 17            Kerala                   33406061                   31841374
# 19    Madhya Pradesh                   72626809                   60348023
# 20       Maharashtra                  112374333                   96878627
# 25   Odisha (Orissa)                   41974218                   36804660
# ...

# %%
plt.figure(figsize=(25,20))
sns.lmplot(hue='Row Labels',x='2011- LIT',y='2011-Murder',data=df1)

# %%
plt.figure(figsize=(25,20))
sns.lmplot(hue='Row Labels',x='2011- LIT',y='2011-Rape',data=df1)

# %%
plt.figure(figsize=(25,20))
sns.lmplot(hue='Row Labels',x='2011- LIT',y='2011-kidnap and abdyction',data=df1)

# %%
plt.figure(figsize=(25,20))
sns.lmplot(hue='Row Labels',x='2011- LIT',y='2011-property crime',data=df1)

# %% [markdown]
# # 2.3	Analysis of year-on-year total crime rate.

# %%
plt.figure(figsize=(70,25))
sns.catplot(x='2011-total crime',hue='Row Labels',y='2001-total crime',data=df1)

# %%
df1
# Out:
#           Row Labels  Sum of Population in 2011  Sum of Population in 2001  \
# 1     Andhra Pradesh                   49386799                   45222736
# 4              Bihar                  104099452                   82998509
# 9              Delhi                   16787941                   13850507
# 11           Gujarat                   60439692                   50671017
# 12           Haryana                   25351462                   21144564
# 13  Himachal Pradesh                    6864602                    6077900
# 16         Karnataka                   61095297                   52850562
# 17            Kerala                   33406061                   31841374
# 19    Madhya Pradesh                   72626809                   60348023
# 20       Maharashtra                  112374333                   96878627
# 25   Odisha (Orissa)                   41974218                   36804660
# ...

# %% [markdown]
# # 2.4	 Analysis of area vs overall crime

# %%
plt.figure(figsize=(25,20))
sns.barplot(x='Row Labels',y='2001-total crime',data=df1)
# Out:
# <Axes: xlabel='Row Labels', ylabel='2001-total crime'>

# %%
plt.figure(figsize=(25,20))
sns.barplot(x='Row Labels',y='2011-total crime',data=df1)
# Out:
# <Axes: xlabel='Row Labels', ylabel='2011-total crime'>

# %% [markdown]
# # 2.5	 Analysis of Population vs overall Crime

# %%
plt.figure(figsize=(25,20))
sns.barplot(x='Sum of Population in 2011',y='2011-total crime',data=df1)
# Out:
# <Axes: xlabel='Sum of Population in 2011', ylabel='2011-total crime'>

# %%
plt.figure(figsize=(25,20))
sns.barplot(x='Sum of Population in 2001',y='2001-total crime',data=df1)
# Out:
# <Axes: xlabel='Sum of Population in 2001', ylabel='2001-total crime'>

# %% [markdown]
# # 2.6	Each state crime report.

# %% [markdown]
# # Crime is mainly related with the population of state. As the population increases crime increases and vice versa.That's why any other factors such as literacy rate having no such impact on crime rate in many states.

# %%
df1
# Out:
#           Row Labels  Sum of Population in 2011  Sum of Population in 2001  \
# 1     Andhra Pradesh                   49386799                   45222736
# 4              Bihar                  104099452                   82998509
# 9              Delhi                   16787941                   13850507
# 11           Gujarat                   60439692                   50671017
# 12           Haryana                   25351462                   21144564
# 13  Himachal Pradesh                    6864602                    6077900
# 16         Karnataka                   61095297                   52850562
# 17            Kerala                   33406061                   31841374
# 19    Madhya Pradesh                   72626809                   60348023
# 20       Maharashtra                  112374333                   96878627
# 25   Odisha (Orissa)                   41974218                   36804660
# ...

# %%
df1.columns
# Out:
# Index(['Row Labels', 'Sum of Population in 2011', 'Sum of Population in 2001',
#        '2001 - LIT', '2011- LIT', '2001 -UNEMP', '2011 -UNEMP', '2001-Murder',
#        '2011-Murder', '2001-Rape', '2011-Rape', '2001-kidnap and abdyction',
#        '2011-kidnap and abdyction', '2001-property crime',
#        '2011-property crime', '2001-total crime', '2011-total crime'],
#       dtype='object')
